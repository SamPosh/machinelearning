# %%
import pandas as pd 
players_info = pd.read_csv("Fifa_players.csv")
players_info.head()
# Out:
# C:\Users\jebarajs\AppData\Local\Temp\ipykernel_13640\2164527262.py:2: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   players_info = pd.read_csv("Fifa_players.csv")
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# ...

# %%
# Remove null value rows
print(players_info.shape)
players_info.describe()
# print(players_info.shape)
# Out:
# (19239, 110)
#            sofifa_id       overall     potential     value_eur       wage_eur  \
# count   19239.000000  19239.000000  19239.000000  1.916500e+04   19178.000000
# mean   231468.086959     65.772182     71.079370  2.850452e+06    9017.989363
# std     27039.717497      6.880232      6.086213  7.613700e+06   19470.176724
# min        41.000000     47.000000     49.000000  9.000000e+03     500.000000
# 25%    214413.500000     61.000000     67.000000  4.750000e+05    1000.000000
# 50%    236543.000000     66.000000     71.000000  9.750000e+05    3000.000000
# 75%    253532.500000     70.000000     75.000000  2.000000e+06    8000.000000
# max    264640.000000     93.000000     95.000000  1.940000e+08  350000.000000
#
#                 age     height_cm     weight_kg   club_team_id  league_level  \
# count  19239.000000  19239.000000  19239.000000   19178.000000  19178.000000
# mean      25.210822    181.299704     74.943032   50580.498123      1.354364
# ...

# %%
players_info.shape
# Out:
# (19239, 110)

# %%
players_info.isna().sum()
# Out:
# sofifa_id               0
# player_url              0
# short_name              0
# long_name               0
# player_positions        0
#                     ...
# player_face_url         0
# club_logo_url          61
# club_flag_url          61
# nation_logo_url     18480
# nation_flag_url         0
# Length: 110, dtype: int64

# %%
players_features = players_info[["overall","potential","value_eur","wage_eur","age"]]
# Remove players row with null values
players_features = players_features.dropna()
print(players_features.shape)
# Out:
# (19165, 5)

# %%
# players_features = players_features.dropna()
players_features.describe()
# Out:
#             overall     potential     value_eur       wage_eur           age
# count  19239.000000  19239.000000  1.916500e+04   19178.000000  19239.000000
# mean      65.772182     71.079370  2.850452e+06    9017.989363     25.210822
# std        6.880232      6.086213  7.613700e+06   19470.176724      4.748235
# min       47.000000     49.000000  9.000000e+03     500.000000     16.000000
# 25%       61.000000     67.000000  4.750000e+05    1000.000000     21.000000
# 50%       66.000000     71.000000  9.750000e+05    3000.000000     25.000000
# 75%       70.000000     75.000000  2.000000e+06    8000.000000     29.000000
# max       93.000000     95.000000  1.940000e+08  350000.000000     54.000000

# %%
from sklearn.preprocessing import StandardScaler

# Scaler for each column value is : (value of column - mean value of column/std deviation of a column)
scaler = StandardScaler()
players_features_sc = scaler.fit_transform(players_feature)
players_features_sc
# Out:
# array([[ 3.95776568,  3.60078658,  9.87056351, 15.96766844,  1.86359972],
#        [ 3.81247225,  3.4365172 , 15.32140647, 13.40033986,  1.44053345],
#        [ 3.66717883,  3.27224782,  5.53615826, 13.40033986,  2.28666598],
#        ...,
#        [-2.725732  , -2.64144996, -0.36125978, -0.4375612 , -0.886331  ],
#        [-2.725732  , -1.82010304, -0.35994632, -0.4375612 , -1.30939726],
#        [-2.725732  , -1.82010304, -0.35994632, -0.4375612 , -1.30939726]])

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

def best_k_means(data,k_max):
    means=[]
    inertias=[]

    for k in range(1,k_max):
        kmeans = KMeans(n_clusters =k)
        kmeans.fit(data)
        means.append(k)
        inertias.append(kmeans.inertia_)

    # elbow plot
    fig = plt.subplots(figsize=(12,5))
    plt.plot(means,inertias,'o-')
    plt.xlabel("K Value")
    plt.ylabel("Inertias")
    plt.grid(True)
    plt.show()

# %%
best_k_means(players_features_sc,10)
# Out:
# C:\Users\jebarajs\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\jebarajs\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\jebarajs\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
# As per the above diagram , best Kmeans is 3. After that variance is very low.

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(players_features_sc)
players_features["K3"] = kmeans.labels_
# Out:
# C:\Users\jebarajs\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
players_feature.shape
# Out:
# (19165, 5)

# %%
players_features_sc.shape
# Out:
# (19165, 5)

# %%
players_features["K3"].unique()
# Out:
# array([1, 0, 2])

# %%
plt.scatter(x=players_features["overall"],y=players_features["potential"],c = players_features["K3"])

# %%
# IF we want to cluster as just 2 partition then we can do this
kmeans = KMeans(n_clusters=2)
kmeans.fit(players_features_sc)
players_features["K2"] = kmeans.labels_
plt.scatter(x=players_features["overall"],y=players_features["potential"],c = players_features["K2"])
# Out:
# C:\Users\jebarajs\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
